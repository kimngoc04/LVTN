# %%
import pandas as pd
import numpy as np
import warnings
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import root_mean_squared_error
import joblib

# Tắt cảnh báo
warnings.filterwarnings('ignore')

print("🚀 BẮT ĐẦU: HUẤN LUYỆN, KIỂM THỬ VÀ XUẤT MÔ HÌNH TỐI ƯU (LR, k=10) - KHÔNG SCALER")

# 1. Đọc dữ liệu
try:
    df = pd.read_csv('../workload_generation/data/periodic_workload.csv')
    print("-> Đã đọc file 'periodic_workload.csv' thành công.")
except FileNotFoundError:
    print("❌ Lỗi: Không tìm thấy file dữ liệu. Vui lòng kiểm tra lại đường dẫn!")
    exit()
# Out:
# 🚀 BẮT ĐẦU: HUẤN LUYỆN, KIỂM THỬ VÀ XUẤT MÔ HÌNH TỐI ƯU (LR, k=10) - KHÔNG SCALER
# -> Đã đọc file 'periodic_workload.csv' thành công.

# %%
# TÍNH TOÁN MỐC CHIA TRAIN/TEST TỰ ĐỘNG VÀ LINH HOẠT
# Lấy mốc thời gian tại vị trí 80% của file dữ liệu gốc
# ---------------------------------------------------------
split_index = int(len(df) * 0.8)
split_time = df.iloc[split_index]['time']
print(f"-> Đã chốt mốc Test bắt đầu từ phút: {split_time}")
# split_time = 180  # Mốc ranh giới chuẩn: Train (phút 1 -> 180), Test trọn vẹn 1 chu kỳ cuối (phút 180 -> 250)
# Out:
# -> Đã chốt mốc Test bắt đầu từ phút: 201

# %%
# 2. Cấu hình thông số tốt nhất
K_BEST = 30

# %%
# 3. Tiền xử lý: Tạo 10 biến trễ (lag features)
print(f"-> Đang tạo {K_BEST} lag features...")
for i in range(1, K_BEST + 1):
    df[f'lag_{i}'] = df['requests'].shift(i)

df = df.dropna()
# Out:
# -> Đang tạo 30 lag features...

# %%
# 4. Phân chia Train/Test bằng split_time đã chốt
train_df = df[df['time'] < split_time]
test_df = df[df['time'] >= split_time]

# Tách Features (X) và Target (y)
X_train = train_df.drop(['time', 'requests'], axis=1)
y_train = train_df['requests']

X_test = test_df.drop(['time', 'requests'], axis=1)
y_test = test_df['requests']
test_time = test_df['time']

# %%
# 5. Huấn luyện mô hình Linear Regression
print("-> Đang huấn luyện mô hình Linear Regression trên dữ liệu thô...")
lr_model = LinearRegression()
lr_model.fit(X_train, y_train)


# =========================================================
# PHẦN KIỂM THỬ (TESTING & EVALUATION)
# =========================================================
print("\n" + "="*50)
print(" ĐÁNH GIÁ TRÊN TẬP TEST (20% DỮ LIỆU CHƯA TỪNG THẤY)")
print("="*50)

# Dự đoán trên tập Test
y_pred = lr_model.predict(X_test)

# Tính sai số
rmse = root_mean_squared_error(y_test, y_pred)
print(f"Sai số RMSE: {rmse:.4f} requests")

# Bảng so sánh
comparison_df = pd.DataFrame({
    'Thời gian (Phút)': test_time, 
    'Tải Thực Tế (Actual)': y_test, 
    'Tải Dự Đoán (Predicted)': y_pred
})
comparison_df['Độ Lệch (Requests)'] = abs(comparison_df['Tải Thực Tế (Actual)'] - comparison_df['Tải Dự Đoán (Predicted)'])

print("\n--- BẢNG SO SÁNH THỰC TẾ VS DỰ ĐOÁN (10 DÒNG ĐẦU) ---")
print(comparison_df.head(10).round(2).to_string(index=False))

# Vẽ biểu đồ
plt.figure(figsize=(12, 5))
plt.plot(test_time, y_test, label='Thực tế (Actual Workload)', color='#1f77b4', linewidth=2, marker='o', markersize=4)
plt.plot(test_time, y_pred, label=f'Dự đoán (LR, k={K_BEST})', color='#ff7f0e', linewidth=2, linestyle='--', marker='x', markersize=4)

plt.title(f'Actual vs Predicted Workload - Best Model: Linear Regression (k={K_BEST})', fontsize=14, fontweight='bold')
plt.xlabel('Time (Minutes)', fontsize=12)
plt.ylabel('Number of Requests', fontsize=12)
plt.legend(fontsize=12, loc='upper left')
plt.grid(True, linestyle='--', alpha=0.6)

plt.tight_layout()
plt.savefig('periodic_lr_k30.png', dpi=300, bbox_inches='tight')
print("\n✅ Đã xuất biểu đồ ra file 'periodic_lr_k30.png'!")
plt.show()
# Out:
# -> Đang huấn luyện mô hình Linear Regression trên dữ liệu thô...
#
# --- KẾT QUẢ TRỌNG SỐ CỦA MÔ HÌNH ELASTIC NET ---
# Hệ số tự do (w0 / intercept): 12795.2004
# Các trọng số của 10 lag features (coef_):
#   lag_1: 0.3105
#   lag_2: 0.0666
#   lag_3: -0.0294
#   lag_4: -0.0513
#   lag_5: 0.2608
#   lag_6: 0.0773
#   lag_7: -0.0528
#   lag_8: -0.1080
#   lag_9: 0.1972
#   lag_10: 0.0131
#   lag_11: 0.0453
#   lag_12: -0.0119
#   lag_13: 0.1314
#   lag_14: -0.0605
#   lag_15: 0.0592
#   lag_16: 0.1229
#   lag_17: -0.1540
#   lag_18: -0.0118
#   lag_19: 0.1080
#   lag_20: -0.0368
#   lag_21: -0.0053
#   lag_22: -0.2222
#   lag_23: 0.0297
#   lag_24: -0.0540
#   lag_25: 0.0482
#   lag_26: -0.0650
#   lag_27: -0.1903
#   lag_28: -0.0420
#   lag_29: 0.0126
#   lag_30: -0.0271
# --------------------------------------------------
#
# ==================================================
#  ĐÁNH GIÁ TRÊN TẬP TEST (20% DỮ LIỆU CHƯA TỪNG THẤY)
# ==================================================
# Sai số RMSE: 26.1050 requests
#
# --- BẢNG SO SÁNH THỰC TẾ VS DỰ ĐOÁN (10 DÒNG ĐẦU) ---
#  Thời gian (Phút)  Tải Thực Tế (Actual)  Tải Dự Đoán (Predicted)  Độ Lệch (Requests)
#               201                  5821                  5805.63               15.37
#               202                  7029                  7021.22                7.78
#               203                  8145                  8136.86                8.14
#               204                  9549                  9545.52                3.48
#               205                 11314                 11355.80               41.80
#               206                 13208                 13223.85               15.85
#               207                 14849                 14833.70               15.30
#               208                 16301                 16305.18                4.18
#               209                 17984                 17999.87               15.87
#               210                 20077                 19991.02               85.98
#
# ✅ Đã xuất biểu đồ ra file 'periodic_lr_k30.png'!

# %%
# --- BỔ SUNG ĐOẠN NÀY ĐỂ XEM TRỌNG SỐ ---
print("\n--- KẾT QUẢ TRỌNG SỐ CỦA MÔ HÌNH ELASTIC NET ---")
print(f"Hệ số tự do (w0 / intercept): {lr_model.intercept_:.4f}")
print("Các trọng số của 10 lag features (coef_):")
for feature_name, weight in zip(X_train.columns, lr_model.coef_):
    print(f"  {feature_name}: {weight:.4f}")
print("-" * 50)
# Out:
# --- KẾT QUẢ TRỌNG SỐ CỦA MÔ HÌNH ELASTIC NET ---
# Hệ số tự do (w0 / intercept): 12795.2004
# Các trọng số của 10 lag features (coef_):
#   lag_1: 0.3105
#   lag_2: 0.0666
#   lag_3: -0.0294
#   lag_4: -0.0513
#   lag_5: 0.2608
#   lag_6: 0.0773
#   lag_7: -0.0528
#   lag_8: -0.1080
#   lag_9: 0.1972
#   lag_10: 0.0131
#   lag_11: 0.0453
#   lag_12: -0.0119
#   lag_13: 0.1314
#   lag_14: -0.0605
#   lag_15: 0.0592
#   lag_16: 0.1229
#   lag_17: -0.1540
#   lag_18: -0.0118
#   lag_19: 0.1080
#   lag_20: -0.0368
#   lag_21: -0.0053
#   lag_22: -0.2222
#   lag_23: 0.0297
#   lag_24: -0.0540
#   lag_25: 0.0482
#   lag_26: -0.0650
#   lag_27: -0.1903
#   lag_28: -0.0420
#   lag_29: 0.0126
#   lag_30: -0.0271
# --------------------------------------------------

# %%
# =========================================================
# XUẤT FILE MÔ HÌNH (EXPORT ARTIFACT)
# =========================================================
# Lưu mô hình dự báo tải
joblib.dump(lr_model, '../workload_forecasting/model/periodic_lr_k30.pkl')

print("\n" + "★"*60)
print("✅ HOÀN TẤT! File đã được tạo sẵn sàng cho Phần V.A:")
print("   -> '../workload_forecasting/model/periodic_lr_30.pkl'")
print("★"*60)
# Out:
# ★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★
# ✅ HOÀN TẤT! File đã được tạo sẵn sàng cho Phần V.A:
#    -> '../workload_forecasting/model/periodic_lr_30.pkl'
# ★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★
